# %%
import pandas as pd

# %%
dataset_view_count = 'nur_data.xlsx'

# %%
df_view_count = pd.read_excel(dataset_view_count, sheetname="nur_data")

# %%
df_view_count.head(1)
# Out:
#       video_id  view_count                                               tags  \
# 0  yDHMwQEHf2E         561  Bosphorus, Uskudar, Eminonu, Istanbul, Kadikoy...
#
#                                            url  duration_in_seconds
# 0  https://www.youtube.com/watch?v=yDHMwQEHf2E                  204

# %%
dataset_archive = 'social spreadsheet.xlsx'

# %%
df_archive = pd.read_excel(dataset_archive, sheetname="CURRENT - Digital Video")
# Out:
# /Users/computer/anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_archive
# Out:
#                            ˚        Who are you?      Video Platform  \
# 0    2018-05-10 13:31:14.614      Srishti Kukreja                NaN
# 1    2018-05-10 15:54:47.912        Mehnaz Yaseen                NaN
# 2                        NaT         Ali Riza San                NaN
# 3    2018-05-10 17:23:37.876       Tahmina Ansari                NaN
# 4    2018-05-10 18:20:32.362                 Safa                NaN
# 5    2018-05-11 15:00:28.230        Mehnaz Yaseen                NaN
# 6    2018-05-11 15:03:32.493      Srishti Kukreja                NaN
# 7    2018-05-11 15:46:28.840         Ali Riza San                NaN
# 8    2018-05-11 16:31:32.070     Khaled Araboghli                NaN
# 9    2018-05-11 16:51:04.345                 Safa                NaN
# 10   2018-05-11 17:11:08.196       Nurdan Erdogan                NaN
# 11   2018-05-11 17:16:29.631                 Safa                NaN
# 12   2018-05-11 17:39:10.052          bilge kotan                NaN
# ...

# %%
count_columns = ['video_id','view_count','duration_in_seconds']

# %%
new_data = pd.DataFrame(pd.DataFrame(df, columns=count_columns ), columns=count_columns )

# %%
new_data
# Out:
#         video_id  view_count  duration_in_seconds
# 0    yDHMwQEHf2E         561                  204
# 1    G-BuJUgB8Mo        2930                   91
# 2    _eXIiH6rkuM        7763                   68
# 3    d4C-Ko8WwG4        3694                  152
# 4    l7vITsWV-I4        5148                   90
# 5    0wn0_Do_tvQ        4261                   83
# 6    TGepcNtPaho         945                   60
# 7    0GYTAJqiTcg       68946                   45
# 8    s4WO4aHUIYc        2104                   96
# 9    -OHgoIZkalM        1046                   52
# 10   8BTMyCKSRPo        6620                   76
# 11   nkcLFix2EbQ       93189                  529
# 12   SZ8hbMlkgrY        1604                  554
# 13   0cZOR-qIWVQ        3782                   42
# 14   oZdLxRCeLbo        1224                   53
# 15   UeyekZdgImU        5802                   67
# 16   LiEgz-S9UCU        1926                   69
# 17   MPJwHYLR5pY        7418                  105
# ...

# %%
df_archive.columns.tolist()
# Out:
# ['˚',
#  'Who are you? ',
#  'Video Platform',
#  'Video Title',
#  'Video Title for Facebook',
#  'Video Title for YouTube',
#  'Facebook Post 1',
#  'Facebook Post 2',
#  'Tweet 1',
#  'Tweet 2',
#  'Tweet 3',
#  'Tweet 4',
#  'Tweet 5',
#  'Tweet 6',
#  'Video Tags for YouTube ',
#  'Video Description (YouTube)',
#  'Expected date and time of publication',
#  'Thumbnail text',
#  'This post should be...',
#  'Edited by',
#  'Copy edited by',
#  'Related article link (From trtworld.com)',
#  'Is it evergreen?',
#  'Justification',
#  'Who is the target audience?',
#  'What is the target time zone?',
#  'Primary Category',
#  'Secondary Category',
#  'Region',
#  'Primary Country',
#  'Country',
#  'Format',
#  'Type',
#  'Length',
#  'Slug Code',
#  'Video Tags for YouTube .1',
#  'Unnamed: 36',
#  'Date Published',
#  'Facebook Link',
#  'Twitter Link',
#  'You Tube Link']

# %%
df_archive.head(1)
# Out:
#                         ˚    Who are you?  Video Platform  \
# 0 2018-05-10 13:31:14.614  Srishti Kukreja            NaN
#
#                             Video Title              Video Title for Facebook  \
# 0  Mohamad Mahathir's stunning comeback  Mohamad Mahathir's stunning comeback
#
#                 Video Title for YouTube  \
# 0  Mohamad Mahathir's stunning comeback
#
#                                      Facebook Post 1 Facebook Post 2  \
# 0  Malaysia's Mahathir Mohamad will become the wo...             NaN
#
#                                              Tweet 1  \
# 0  Malaysia's Mahathir Mohamad is back in action ...
#
#                                              Tweet 2      ...       \
# 0  Dr M's back after a breathtaking election win....      ...
#
#        Format     Type                Length Slug Code  \
# 0  Fast Video  Serious  Between 1min - 2mins       NaN
#
#   Video Tags for YouTube .1 Unnamed: 36 Date Published Facebook Link  \
# ...

# %%
archive_columns = [
 'Video Title',
 'Video Title for YouTube',
 'Video Tags for YouTube ',
 'Video Description (YouTube)',
 'Thumbnail text',
 'Is it evergreen?',
 'Who is the target audience?',
 'Primary Category',
 'Secondary Category',
 'Region',
 'Primary Country',
 'Country',
 'Format',
 'Type',
 'Length',
 'Date Published',
 'You Tube Link']

# %%
df_archive = df_archive.filter(items=archive_columns)

# %%
del df_archive['You Tube Link']
del df_archive['ids']

# %%
df_archive
# Out:
#                                             Video Title  \
# 977              One year since the beginning of #MeToo
# 978   How would Saudi Arabia retaliate if US imposes...
# 979   Man holds out in family home through years of ...
# 985     Harvard accused of bias against Asian-Americans
# 988                           Interrogation gone wrong?
# 989   Russian Orthodox Church severs links with Orth...
# 990   Will Saudi Arabia confess to killing Jamal Kha...
# 991                           Private armies for rent
# 992       India changes name of historic city Allahabad
# 993   Why are Serbia and Kosovo considering a land s...
# 996   5 questions Saudi Arabia has failed to answer ...
# 997   Afghanistan's parliamentary elections: 5 thing...
# 998     Mohammed bin Salman's PR efforts gone to waste?
# 999                                     What is famine?
# 1000  Honduran migrant caravan is heading towards th...
# 1001                     Jamal Khashoggi's final column
# ...

# %%
df_archive = df_archive.dropna(subset=['You Tube Link'])

# %%
df_archive.shape
# Out:
# (222, 17)

# %%
df_archive = df_archive[df_archive['You Tube Link'].str.contains("https://www.youtube.com/watch?")]

# %%
df_archive.shape
# Out:
# (207, 17)

# %%
df_archive['ids'] = df_archive['You Tube Link'].str.split("?", n = 1, expand = True)[1]

# %%
df_archive['id'] = df_archive['ids'].str.split("&", n = 1, expand = True)[0]

# %%
df_archive['id'] = df_archive['id'].str.split("=", n = 1, expand = True)[1]

# %%
df_archive['video_id'] = df_archive['id']

# %%
del  df_archive['id']

# %%
df_archive  = df_archive.drop[]
# Out:
#                                             Video Title  \
# 977              One year since the beginning of #MeToo
# 978   How would Saudi Arabia retaliate if US imposes...
# 979   Man holds out in family home through years of ...
# 985     Harvard accused of bias against Asian-Americans
# 988                           Interrogation gone wrong?
# 989   Russian Orthodox Church severs links with Orth...
# 990   Will Saudi Arabia confess to killing Jamal Kha...
# 991                           Private armies for rent
# 992       India changes name of historic city Allahabad
# 993   Why are Serbia and Kosovo considering a land s...
# 996   5 questions Saudi Arabia has failed to answer ...
# 997   Afghanistan's parliamentary elections: 5 thing...
# 998     Mohammed bin Salman's PR efforts gone to waste?
# 999                                     What is famine?
# 1000  Honduran migrant caravan is heading towards th...
# 1001                     Jamal Khashoggi's final column
# ...

# %%
id_list = list(set(df_archive['id']).intersection(set(new_data['video_id'])))

# %%
frames = [df_archive, new_data]

# %%
 deneme = pd.concat(frames,join='inner')

# %%
nur_data = pd.merge(df_archive, new_data, on='video_id')

# %%
nur_data.head(2)
# Out:
#                                          Video Title  \
# 0             One year since the beginning of #MeToo
# 1  How would Saudi Arabia retaliate if US imposes...
#
#                              Video Title for YouTube  \
# 0                    One year of the #MeToo movement
# 1  How would Saudi Arabia retaliate if US imposes...
#
#                              Video Tags for YouTube   \
# 0       #MeToo #TimeIsUp #US #ElisaMilano #AnaKaman
# 1  Saudi Arabia, sanctions, USA, US, Jamal Khasho...
#
#                          Video Description (YouTube)      Thumbnail text  \
# 0  One year after #MeToo went viral and turned in...  The year of #MeToo
# 1  An op-ed in Saudi-owned Al Arabiya news has wa...      Saudi warning?
#
#   Is it evergreen? Who is the target audience?           Primary Category  \
# 0               No                         NaN  Discrimination and Racism
# 1               No                         NaN                   Politics
#
# ...

# %%
nur_data.to_csv('dataset.csv', encoding='utf-8', index=False)

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
# Missing values statistics
missing_values = missing_values_table(nur_data)
missing_values
# Out:
# Your selected dataframe has 19 columns.
# There are 9 columns that have missing values.
#                              Missing Values  % of Total Values
# Date Published                          205              100.0
# Country                                 123               60.0
# Who is the target audience?             115               56.1
# Region                                  105               51.2
# Primary Country                           6                2.9
# Video Tags for YouTube                    4                2.0
# Video Description (YouTube)               3                1.5
# Video Title                               2                1.0
# Thumbnail text                            2                1.0

# %%
del nur_data['Date Published']

# %%
del nur_data['Country']

# %%
del nur_data['Who is the target audience?']

# %%
del nur_data['Region']

# %%
nur_data.to_csv('nur_dataset.csv', encoding='utf-8', index=False)
